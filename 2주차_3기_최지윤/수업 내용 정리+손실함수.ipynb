# %% [markdown]
# # 수업 내용 정리!

# %% [markdown]
# # 지도 학습
# - 회귀 (Regression) : 연속적인 수치 값을 예측하는 것 *(ex: 주택 가격)*
#
# - 분류 (Classification) :이산적인 범주나 클래스를 예측하는 문제, 확률 계산해서 예측하는 문제 *(ex: 스팸 메세지)*

# %% [markdown]
# # ☘

# %% [markdown]
# # 회귀(Regression)
# *입력 X를 받아서 출력 Y(연속적)를 예측하는 것.*
#
#
# ---
#
#
# 예측값과 실제값 차이를 최소화 하는 것이 관건.
#
#
# ---
#
#
# 1. Linear Regression (선형 회귀)
# - x값은 데이터에 따라 정해져 있고,
# 결국 w값(파라미터)을 맞추는게 관건
#
# - 손실 함수(loss  function): 예측한 값이란 실제 값 사이의 차이를 수치적으로 알 수 있게 해주는
#
#
# ---
#
#
#
# 2. Polynomial Regression (다항 회귀)
# - 선형 회귀에서 조금 발달된?
# - 차수가 작고 높고의 문제는
# 과대적합*(overfitting)*, 과소적합 *(underfitting)* 문제와 직결
#
#
# ---
#
#
# 3. Ridge/Lasso (릿지/라쏘)
# - 규제(regularization):과대적합*(overfitting)* 방지하려고

# %% [markdown]
# # ☘

# %% [markdown]
# # 분류(Classification)
# *입력 X 받아서 Y값(이산적) 예측 하는 것.*
#
#
# ---
# - 퍼셉트론*(perceptron)*: 이진 분류에 사용, 엄청 초창기 분류 문제
#
#
# ---
#
#
# - SVM*(support vector machine)* : 최대 마진 찾는 것.
# - 마진 = 두 클래스 사이 간격.
#
#
# ---
#
#
# - Logistic/softmaxRegression
# - 말만 회귀 (이진 분류 / 다중 분류)

# %% [markdown]
# # ☘

# %% [markdown]
# # Tree Model
# ---
#
#
# 1.   Decision Tree Regressor  *# 회귀*
# - 데이터를 여러 구간으로 나눠 각 구간 내에서 예측값 내는 것
# - Decision Tree Regressor에서는 MSE나 분산(데이터가 얼마나 잘 몰려있는지)을 지표로 주로 사용
#
#
#
# ---
#
#
# 2.   Decision Tree Classifier  *# 분류*
# - 데이터 특성 기준으로 의사결정 규칙 만들어서 분류 하는 모델
#
# ---
#
#
# 3.   Random Forest Classifier  *# 분류*
#
#
# ---
#
#
# 4.   Gradient Boosting Regressor  *# 회귀*

# %% [markdown]
# # ☘

# %% [markdown]
# # + @
#
# overfitting 과적합 - 앙상블 기법으로 막을 수 있어요용

# %% [markdown]
# # 회귀 문제에서의 손실함수
#
#
#
# ---
#
#
#
# 1.   평균 절대 오차 / MAE (Mean Absolute Error)
#
# ![image.png](data:image/png;base64,...)
#
# - 예측 값과 정답 값의 차이에 절댓값 -> 그 값들을 전부 더하고 -> 개수 N으로 나누어 평균을 낸 값
#
# - 예측 결과와 정답 결과가 떨어진 정도의 절댓값을 평균 낸 것이기에, 전체 데이터의 학습된 정도를 쉽게 파악 가능
#
# - 절대값 때문에 어떤 식으로 오차가 발생했는지, 음수인지 양수인지 판단할 수 없다
#
# - 또한 아래 그림처럼 최적의 값에 가까워지더라도 이동거리가 일정하기 때문에 최적의 값에 수렴하기 어렵다.
#
# ---
#
#
# 2.   평균 제곱 오차 / MSE (Mean Squared Error)
#
# ![image.png](data:image/png;base64,...)
# - 가장 많이 쓰이는 손실 함수 중 하나
#
# - 예측 값과 실제 값 사이의 평균을 제곱하여 평균을 낸 값
#
# - 제곱 연산으로 인해 차이가 커질수록 MSE값이 뚜렷해지며 제곱으로 인해 오차가 양수든 음수든 누적 값을 증가시킴
#
# - 하지만 제곱으로 인해 "1 미만의 값은 더 작아지고, 그 이상의 값은 더 커진다”, 즉 값의 왜곡 발생
#
# - MAE와 달리 최적 값에 가까워질 경우 (함수가 convex 굴곡형태이기 때문!!) 이동거리가 다르게 변화하기 때문에 최적 값에 수렴하기 용이하다
#
# ---
#
#
# 3.   평균 제곱근 오차 / RMSE (Root Mean Square Error)
#
# ![image.png](data:image/png;base64,...)
# - MSE에서 값을 제곱해서 생기는 왜곡이 줄어들며, 오차를 보다 직관적으로 보여줌
